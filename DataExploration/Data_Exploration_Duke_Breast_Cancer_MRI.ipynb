# %% [markdown]
# # Data Exporation Duke Breast Cancer MRI
#
# - **Dynamic contrast-enhanced magnetic resonance images of breast cancer patients with tumor locations (Duke-Breast-Cancer-MRI)**: https://wiki.cancerimagingarchive.net/pages/viewpage.action?pageId=70226903

# %%
import pandas as pd
import numpy as np
import os
import pydicom as dicom
from tqdm import tqdm
from skimage.io import imsave
import matplotlib.pylab as plt
import seaborn as sns

# %% [markdown]
# ## Load Lesion Annotation Boxes Excel

# %%
annot_boxes_df = pd.read_excel("/media/james/My Passport/Jetson_TX2_CMPE258/duke-breast-cancer-mri/Annotation_Boxes.xlsx", index_col=None, names=["Patient ID","Start Row","End Row","Start Column", "End Column", "Start Slice", "End Slice"])
annot_boxes_df.head()
# Out:
#        Patient ID  Start Row  End Row  Start Column  End Column  Start Slice  \
# 0  Breast_MRI_001        234      271           308         341           89
# 1  Breast_MRI_002        251      294           108         136           59
# 2  Breast_MRI_003        351      412            82         139           96
# 3  Breast_MRI_004        262      280           193         204           86
# 4  Breast_MRI_005        188      213           138         178           76
#
#    End Slice
# 0        112
# 1         72
# 2        108
# 3         95
# 4        122

# %% [markdown]
# ## Load Breast Radiologist Density Assessment Excel

# %%
radiologist_density_asmt_df = pd.read_excel("/media/james/My Passport/Jetson_TX2_CMPE258/duke-breast-cancer-mri/Breast_Radiologist_Density_Assessments.xlsx", index_col=None, names=["Subject_ID","Radiologist A","Radiologist B","Radiologist C","BI‐RADS density categories"])
radiologist_density_asmt_df.head()
# Out:
#        Subject_ID Radiologist A Radiologist B Radiologist C  \
# 0  Breast_MRI_010             c             c             c
# 1  Breast_MRI_014             b             c             c
# 2  Breast_MRI_026             a             b             b
# 3  Breast_MRI_029             a             b             a
# 4  Breast_MRI_038             b             c             b
#
#    BI‐RADS density categories
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN

# %% [markdown]
# ## Load Clinical and Other Features Excel

# %%
clinical_features_df = pd.read_excel("/media/james/My Passport/Jetson_TX2_CMPE258/duke-breast-cancer-mri/Clinical_and_Other_Features.xlsx", index_col=None, header=None)
clinical_features_df.head()
# Out:
#                     0                                         1   \
# 0  Patient Information                 MRI Technical Information
# 1           Patient ID  Days to MRI (From the Date of Diagnosis)
# 2                  NaN                                       NaN
# 3       Breast_MRI_001                                         6
# 4       Breast_MRI_002                                        12
#
#                                                   2   \
# 0                                                NaN
# 1                                       Manufacturer
# 2  GE MEDICAL SYSTEMS=0, MPTronic software=1, SIE...
# 3                                                  2
# 4                                                  0
#
#                                                   3   \
# 0                                                NaN
# 1                            Manufacturer Model Name
# 2  Avanto=0, Optima MR450w=1, SIGNA EXCITE=2, SIG...
# 3                                                  0
# 4                                                  4
#
#                                                   4   \
# 0                                                NaN
# 1                                       Scan Options
# 2  FAST_GEMS\SAT_GEMS\ACC_GEMS\PFP\FS=0,FAST_GEMS...
# 3                                                  5
# 4                                                  1
#
#                            5                            6   \
# 0                         NaN                          NaN
# 1      Field Strength (Tesla)  Patient Position During MRI
# 2  1.494=0,1.5=1,2.8936=2,3=3                  FFP=0,HFP=1
# 3                           1                            0
# 4                           3                            0
#
#                                 7   \
# 0                              NaN
# 1        Image Position of Patient
# 2                              NaN
# 3  -191.8003 X -176.1259 X 86.6065
# 4      154.724 X 176.048 X 94.5771
#
#                                                   8   \
# 0                                                NaN
# 1                                     Contrast Agent
# 2  GADAVIST=0,MAGNEVIST=1,MMAGNEVIST=2,MULTIHANCE...
# 3                                                  1
# 4                                                  1
#
#                                                   9   ...  \
# 0                                                NaN  ...
# 1                         Contrast Bolus Volume (mL)  ...
# 2  6=0,7=1,8=2,9=3,10=4,11=5,11.88=6,12=7,13=8,13...  ...
# 3                                                 15  ...
# 4                                                NaN  ...
#
#                                                   88  \
# 0                                                NaN
# 1  Therapeutic or Prophylactic Oophorectomy as pa...
# 2              {0 = no, 1 = yes, NP = not pertinent}
# 3                                                  1
# 4                                                  0
#
#                                   89                               90  \
# 0              Anti-Her2 Neu Therapy                              NaN
# 1  Neoadjuvant Anti-Her2 Neu Therapy  Adjuvant Anti-Her2 Neu Therapy
# 2                  {0 = no, 1 = yes}                {0 = no, 1 = yes}
# 3                                  1                                1
# 4                                  0                                0
#
#                                        91  \
# 0                     Neoadjuvant therapy
# 1     Received Neoadjuvant Therapy or Not
# 2  {1 = yes, 2 = no, NA = not applicable}
# 3                                       1
# 4                                       1
#
#                                                   92  \
# 0         Pathologic Response to Neoadjuvant Therapy
# 1  Pathologic response to Neoadjuvant therapy: Pa...
# 2  { -1 = TX;  0 = T0;  1 = T1;  2 = T2;  3 = T3;...
# 3                                                  1
# 4                                                NaN
#
#                                                   93  \
# 0                                                NaN
# 1  Pathologic response to Neoadjuvant therapy:  P...
# 2   { -1 = NX;  0 = N0;  1 = N1;  2 = N2;  3 = N3...
# 3                                                 -1
# 4                                                NaN
#
#                                                   94  \
# 0                                                NaN
# 1  Pathologic response to Neoadjuvant therapy:  P...
# 2  { -1 = MX;  0 = M0;  1 = M1;  NA = not applica...
# 3                                                 -1
# 4                                                NaN
#
#                                                   95  \
# 0                             Near Complete Response
# 1  Overall Near-complete Response:  Stricter Defi...
# 2  {0 = not complete or near-complete, 1 = comple...
# 3                                                  0
# 4                                                  2
#
#                                                   96  \
# 0                                                NaN
# 1  Overall Near-complete Response:  Looser Defini...
# 2  {0 = not complete or near-complete, 1 = comple...
# 3                                                  0
# 4                                                  2
#
#                                                   97
# 0                                                NaN
# 1            Near-complete Response (Graded Measure)
# 2  {0 = Not complete or near-complete;  1 = Compl...
# 3                                                  0
# 4                                                  4
#
# [5 rows x 98 columns]

# %%
# grab row 2, put into list, show top 5
clinical_features_header = clinical_features_df.loc[1,:].values.tolist()

# %%
clinical_features_header[:5]
# Out:
# ['Patient ID',
#  'Days to MRI (From the Date of Diagnosis)',
#  'Manufacturer',
#  'Manufacturer Model Name',
#  'Scan Options']

# %%
len(clinical_features_header)
# Out:
# 98

# %%
# get rid of first 2 rows, insert the header from the second row
clinical_features_df = clinical_features_df[2:]
clinical_features_df.columns = clinical_features_header

# %%
clinical_features_df.head()
# Out:
#        Patient ID Days to MRI (From the Date of Diagnosis)  \
# 2             NaN                                      NaN
# 3  Breast_MRI_001                                        6
# 4  Breast_MRI_002                                       12
# 5  Breast_MRI_003                                       10
# 6  Breast_MRI_004                                       18
#
#                                         Manufacturer  \
# 2  GE MEDICAL SYSTEMS=0, MPTronic software=1, SIE...
# 3                                                  2
# 4                                                  0
# 5                                                  0
# 6                                                  0
#
#                              Manufacturer Model Name  \
# 2  Avanto=0, Optima MR450w=1, SIGNA EXCITE=2, SIG...
# 3                                                  0
# 4                                                  4
# 5                                                  3
# 6                                                  4
#
#                                         Scan Options  \
# 2  FAST_GEMS\SAT_GEMS\ACC_GEMS\PFP\FS=0,FAST_GEMS...
# 3                                                  5
# 4                                                  1
# 5                                                  2
# 6                                                  1
#
#        Field Strength (Tesla) Patient Position During MRI  \
# 2  1.494=0,1.5=1,2.8936=2,3=3                 FFP=0,HFP=1
# 3                           1                           0
# 4                           3                           0
# 5                           3                           0
# 6                           1                           0
#
#          Image Position of Patient  \
# 2                              NaN
# 3  -191.8003 X -176.1259 X 86.6065
# 4      154.724 X 176.048 X 94.5771
# 5      174.658 X 228.317 X 88.4878
# 6      188.148 X 194.282 X 94.1832
#
#                                       Contrast Agent  \
# 2  GADAVIST=0,MAGNEVIST=1,MMAGNEVIST=2,MULTIHANCE...
# 3                                                  1
# 4                                                  1
# 5                                                  1
# 6                                                  1
#
#                           Contrast Bolus Volume (mL)  ...  \
# 2  6=0,7=1,8=2,9=3,10=4,11=5,11.88=6,12=7,13=8,13...  ...
# 3                                                 15  ...
# 4                                                NaN  ...
# 5                                                NaN  ...
# 6                                                NaN  ...
#
#   Therapeutic or Prophylactic Oophorectomy as part of Endocrine Therapy   \
# 2              {0 = no, 1 = yes, NP = not pertinent}
# 3                                                  1
# 4                                                  0
# 5                                                  0
# 6                                                  0
#
#   Neoadjuvant Anti-Her2 Neu Therapy Adjuvant Anti-Her2 Neu Therapy   \
# 2                 {0 = no, 1 = yes}               {0 = no, 1 = yes}
# 3                                 1                               1
# 4                                 0                               0
# 5                                 0                               0
# 6                                 0                               0
#
#       Received Neoadjuvant Therapy or Not  \
# 2  {1 = yes, 2 = no, NA = not applicable}
# 3                                       1
# 4                                       1
# 5                                       1
# 6                                       2
#
#   Pathologic response to Neoadjuvant therapy: Pathologic stage (T) following neoadjuvant therapy   \
# 2  { -1 = TX;  0 = T0;  1 = T1;  2 = T2;  3 = T3;...
# 3                                                  1
# 4                                                NaN
# 5                                                  1
# 6                                                NaN
#
#   Pathologic response to Neoadjuvant therapy:  Pathologic stage (N) following neoadjuvant therapy  \
# 2   { -1 = NX;  0 = N0;  1 = N1;  2 = N2;  3 = N3...
# 3                                                 -1
# 4                                                NaN
# 5                                                  1
# 6                                                NaN
#
#   Pathologic response to Neoadjuvant therapy:  Pathologic stage (M) following neoadjuvant therapy   \
# 2  { -1 = MX;  0 = M0;  1 = M1;  NA = not applica...
# 3                                                 -1
# 4                                                NaN
# 5                                                 -1
# 6                                                NaN
#
#   Overall Near-complete Response:  Stricter Definition  \
# 2  {0 = not complete or near-complete, 1 = comple...
# 3                                                  0
# 4                                                  2
# 5                                                  0
# 6                                                NaN
#
#   Overall Near-complete Response:  Looser Definition  \
# 2  {0 = not complete or near-complete, 1 = comple...
# 3                                                  0
# 4                                                  2
# 5                                                  0
# 6                                                NaN
#
#              Near-complete Response (Graded Measure)
# 2  {0 = Not complete or near-complete;  1 = Compl...
# 3                                                  0
# 4                                                  4
# 5                                                  0
# 6                                                NaN
#
# [5 rows x 98 columns]

# %% [markdown]
# ## Load Imaging Features Excel

# %%
imaging_features_df = pd.read_excel("/media/james/My Passport/Jetson_TX2_CMPE258/duke-breast-cancer-mri/Imaging_Features.xlsx", index_col=None, header=None)
imaging_features_df.head()
# Out:
#               0                                 1    \
# 0      Patient ID  F1_DT_POSTCON (T11=0.05,T12=0.5)
# 1  Breast_MRI_001                                 1
# 2  Breast_MRI_002                                 1
# 3  Breast_MRI_003                          0.174775
# 4  Breast_MRI_004                          0.086546
#
#                                 2                                 3    \
# 0  F1_DT_POSTCON (T11=0.05,T12=0.1)  F1_DT_POSTCON (T11=0.02,T12=0.5)
# 1                          0.120721                          0.530395
# 2                          0.129546                          0.485217
# 3                          0.062051                           0.06991
# 4                          0.045111                          0.034619
#
#                                 4                                 5    \
# 0  F1_DT_POSTCON (T11=0.02,T12=0.8)  F1_DT_POSTCON (T11=0.05,T12=0.8)
# 1                                 1                                 1
# 2                                 1                                 1
# 3                          0.132265                          0.330662
# 4                          0.051265                          0.128162
#
#                                6                                7    \
# 0  F1_DT_POSTCON (T11=0.1,T12=0.5)  F1_DT_POSTCON (T11=0.1,T12=0.8)
# 1                                1                                1
# 2                                1                                1
# 3                          0.34955                         0.661324
# 4                         0.173093                         0.256325
#
#                                8                                9    ...  \
# 0  F1_DT_POSTCON (T11=0.2,T12=0.5)  F1_DT_POSTCON (T11=0.2,T12=0.8)  ...
# 1                                1                                1  ...
# 2                                1                                1  ...
# 3                           0.6991                                1  ...
# 4                         0.346185                          0.51265  ...
#
#                                                 520  \
# 0  WashinRate_map_difference_entropy_tissue_PostCon
# 1                                          3.380663
# 2                                          3.444474
# 3                                          3.478455
# 4                                          3.389678
#
#                                                  521  \
# 0  WashinRate_map_information_measure_correlation...
# 1                                          -0.025575
# 2                                          -0.036063
# 3                                           -0.04373
# 4                                          -0.017802
#
#                                                  522  \
# 0  WashinRate_map_information_measure_correlation...
# 1                                           0.422391
# 2                                           0.505652
# 3                                           0.546674
# 4                                           0.363818
#
#                                                  523  \
# 0  WashinRate_map_inverse_difference_is_homom_tis...
# 1                                           0.171959
# 2                                           0.177087
# 3                                           0.170507
# 4                                            0.17721
#
#                                                  524  \
# 0  WashinRate_map_inverse_difference_normalized_t...
# 1                                           0.960359
# 2                                           0.959067
# 3                                           0.957527
# 4                                           0.960705
#
#                                                  525  \
# 0  WashinRate_map_inverse_difference_moment_norma...
# 1                                           0.996829
# 2                                           0.996363
# 3                                           0.995981
# 4                                           0.996827
#
#                                   526                                    527  \
# 0  WashinRate_map_mean_tissue_PostCon  WashinRate_map_std_dev_tissue_PostCon
# 1                           14.517894                              20.347506
# 2                            47.29795                              83.909561
# 3                          114.171582                             129.252343
# 4                           33.499175                              69.164227
#
#                                       528  \
# 0  WashinRate_map_skewness_tissue_PostCon
# 1                                 1.62587
# 2                                0.251498
# 3                                1.928743
# 4                                1.171314
#
#                                       529
# 0  WashinRate_map_kurtosis_tissue_PostCon
# 1                               11.406955
# 2                                5.659428
# 3                               11.554948
# 4                                8.493319
#
# [5 rows x 530 columns]

# %%
imaging_features_header = imaging_features_df.loc[0,:].values.tolist()

# %%
imaging_features_header[:5]
# Out:
# ['Patient ID',
#  'F1_DT_POSTCON (T11=0.05,T12=0.5)',
#  'F1_DT_POSTCON (T11=0.05,T12=0.1)',
#  'F1_DT_POSTCON (T11=0.02,T12=0.5)',
#  'F1_DT_POSTCON (T11=0.02,T12=0.8)']

# %%
# get rid of first row, insert the header from the first row
imaging_features_df = imaging_features_df[1:]
imaging_features_df.columns = imaging_features_header

# %%
imaging_features_df.head()
# Out:
#        Patient ID F1_DT_POSTCON (T11=0.05,T12=0.5)  \
# 1  Breast_MRI_001                                1
# 2  Breast_MRI_002                                1
# 3  Breast_MRI_003                         0.174775
# 4  Breast_MRI_004                         0.086546
# 5  Breast_MRI_005                         0.289669
#
#   F1_DT_POSTCON (T11=0.05,T12=0.1) F1_DT_POSTCON (T11=0.02,T12=0.5)  \
# 1                         0.120721                         0.530395
# 2                         0.129546                         0.485217
# 3                         0.062051                          0.06991
# 4                         0.045111                         0.034619
# 5                         0.052031                         0.115868
#
#   F1_DT_POSTCON (T11=0.02,T12=0.8) F1_DT_POSTCON (T11=0.05,T12=0.8)  \
# 1                                1                                1
# 2                                1                                1
# 3                         0.132265                         0.330662
# 4                         0.051265                         0.128162
# 5                         0.378575                         0.839984
#
#   F1_DT_POSTCON (T11=0.1,T12=0.5) F1_DT_POSTCON (T11=0.1,T12=0.8)  \
# 1                               1                               1
# 2                               1                               1
# 3                         0.34955                        0.661324
# 4                        0.173093                        0.256325
# 5                        0.579338                               1
#
#   F1_DT_POSTCON (T11=0.2,T12=0.5) F1_DT_POSTCON (T11=0.2,T12=0.8)  ...  \
# 1                               1                               1  ...
# 2                               1                               1  ...
# 3                          0.6991                               1  ...
# 4                        0.346185                         0.51265  ...
# 5                        0.958287                               1  ...
#
#   WashinRate_map_difference_entropy_tissue_PostCon  \
# 1                                         3.380663
# 2                                         3.444474
# 3                                         3.478455
# 4                                         3.389678
# 5                                         4.009938
#
#   WashinRate_map_information_measure_correlation1_tissue_PostCon  \
# 1                                          -0.025575
# 2                                          -0.036063
# 3                                           -0.04373
# 4                                          -0.017802
# 5                                          -0.049294
#
#   WashinRate_map_information_measure_correlation2_tissue_PostCon  \
# 1                                           0.422391
# 2                                           0.505652
# 3                                           0.546674
# 4                                           0.363818
# 5                                           0.603426
#
#   WashinRate_map_inverse_difference_is_homom_tissue_PostCon  \
# 1                                           0.171959
# 2                                           0.177087
# 3                                           0.170507
# 4                                            0.17721
# 5                                           0.117966
#
#   WashinRate_map_inverse_difference_normalized_tissue_PostCon  \
# 1                                           0.960359
# 2                                           0.959067
# 3                                           0.957527
# 4                                           0.960705
# 5                                           0.930624
#
#   WashinRate_map_inverse_difference_moment_normalized_tissue_PostCon  \
# 1                                           0.996829
# 2                                           0.996363
# 3                                           0.995981
# 4                                           0.996827
# 5                                           0.989135
#
#   WashinRate_map_mean_tissue_PostCon WashinRate_map_std_dev_tissue_PostCon  \
# 1                          14.517894                             20.347506
# 2                           47.29795                             83.909561
# 3                         114.171582                            129.252343
# 4                          33.499175                             69.164227
# 5                          34.406635                             26.951415
#
#   WashinRate_map_skewness_tissue_PostCon  \
# 1                                1.62587
# 2                               0.251498
# 3                               1.928743
# 4                               1.171314
# 5                               0.985464
#
#   WashinRate_map_kurtosis_tissue_PostCon
# 1                              11.406955
# 2                               5.659428
# 3                              11.554948
# 4                               8.493319
# 5                               4.331451
#
# [5 rows x 530 columns]

# %% [markdown]
# ## Load Breast Cancer MRI Filepath Filename Mapping Excel

# %%
bc_mri_path_file_mapping_df = pd.read_excel("/media/james/My Passport/Jetson_TX2_CMPE258/duke-breast-cancer-mri/Breast-Cancer-MRI-filepath_filename-mapping.xlsx", index_col=None, header=None)
bc_mri_path_file_mapping_df.head()
# Out:
#                                                   0   \
# 0                                   sop_instance_UID
# 1  1.3.6.1.4.1.14519.5.2.1.1805789812895034139917...
# 2  1.3.6.1.4.1.14519.5.2.1.4903237729147735321973...
# 3  1.3.6.1.4.1.14519.5.2.1.3061160038794820079325...
# 4  1.3.6.1.4.1.14519.5.2.1.1574717199045785031549...
#
#                                                   1   \
# 0                         original_path_and_filename
# 1  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
# 2  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
# 3  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
# 4  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
#
#                                                   2   \
# 0                                       classic_path
# 1  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
# 2  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
# 3  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
# 4  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
#
#                                                   3   4   5   6   7   8   9   \
# 0                                   descriptive_path NaN NaN NaN NaN NaN NaN
# 1  Duke-Breast-Cancer-MRI/BreastMRI001/01-01-1990... NaN NaN NaN NaN NaN NaN
# 2  Duke-Breast-Cancer-MRI/BreastMRI001/01-01-1990... NaN NaN NaN NaN NaN NaN
# 3  Duke-Breast-Cancer-MRI/BreastMRI001/01-01-1990... NaN NaN NaN NaN NaN NaN
# 4  Duke-Breast-Cancer-MRI/BreastMRI001/01-01-1990... NaN NaN NaN NaN NaN NaN
#
#    10  11  12  13  14           15
# 0 NaN NaN NaN NaN NaN  series_sort
# 1 NaN NaN NaN NaN NaN       01.dcm
# 2 NaN NaN NaN NaN NaN          NaN
# 3 NaN NaN NaN NaN NaN          NaN
# 4 NaN NaN NaN NaN NaN          NaN

# %%
drop_nan_cols_list = bc_mri_path_file_mapping_df.columns[4:].values.tolist()

# %%
bc_mri_path_file_mapping_df = bc_mri_path_file_mapping_df.drop(drop_nan_cols_list, axis=1)

# %%
bc_mri_path_file_mapping_df.head()
# Out:
#                                                    0  \
# 0                                   sop_instance_UID
# 1  1.3.6.1.4.1.14519.5.2.1.1805789812895034139917...
# 2  1.3.6.1.4.1.14519.5.2.1.4903237729147735321973...
# 3  1.3.6.1.4.1.14519.5.2.1.3061160038794820079325...
# 4  1.3.6.1.4.1.14519.5.2.1.1574717199045785031549...
#
#                                                    1  \
# 0                         original_path_and_filename
# 1  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
# 2  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
# 3  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
# 4  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
#
#                                                    2  \
# 0                                       classic_path
# 1  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
# 2  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
# 3  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
# 4  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
#
#                                                    3
# 0                                   descriptive_path
# 1  Duke-Breast-Cancer-MRI/BreastMRI001/01-01-1990...
# 2  Duke-Breast-Cancer-MRI/BreastMRI001/01-01-1990...
# 3  Duke-Breast-Cancer-MRI/BreastMRI001/01-01-1990...
# 4  Duke-Breast-Cancer-MRI/BreastMRI001/01-01-1990...

# %%
bc_mri_path_file_mapping_header = bc_mri_path_file_mapping_df.loc[0,:].values.tolist()

# %%
bc_mri_path_file_mapping_df = bc_mri_path_file_mapping_df[1:]
bc_mri_path_file_mapping_df.columns = bc_mri_path_file_mapping_header

# %%
bc_mri_path_file_mapping_df.head()
# Out:
#                                     sop_instance_UID  \
# 1  1.3.6.1.4.1.14519.5.2.1.1805789812895034139917...
# 2  1.3.6.1.4.1.14519.5.2.1.4903237729147735321973...
# 3  1.3.6.1.4.1.14519.5.2.1.3061160038794820079325...
# 4  1.3.6.1.4.1.14519.5.2.1.1574717199045785031549...
# 5  1.3.6.1.4.1.14519.5.2.1.2594404476894572978078...
#
#                           original_path_and_filename  \
# 1  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
# 2  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
# 3  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
# 4  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
# 5  DICOM_Images/Breast_MRI_001/post_1/Breast_MRI_...
#
#                                         classic_path  \
# 1  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
# 2  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
# 3  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
# 4  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
# 5  Duke-Breast-Cancer-MRI/Breast_MRI_001/1.3.6.1....
#
#                                     descriptive_path
# 1  Duke-Breast-Cancer-MRI/BreastMRI001/01-01-1990...
# 2  Duke-Breast-Cancer-MRI/BreastMRI001/01-01-1990...
# 3  Duke-Breast-Cancer-MRI/BreastMRI001/01-01-1990...
# 4  Duke-Breast-Cancer-MRI/BreastMRI001/01-01-1990...
# 5  Duke-Breast-Cancer-MRI/BreastMRI001/01-01-1990...

# %% [markdown]
# ## Load Breast Cancer Segmentation Filepath Mapping CSV

# %%
bc_seg_file_mapping_df = pd.read_csv("/media/james/My Passport/Jetson_TX2_CMPE258/duke-breast-cancer-mri/segmentation_filepath_mapping.csv")
bc_seg_file_mapping_df.head()
# Out:
#        Patient ID             Segmentation Label Slice File  \
# 0  Breast_MRI_002         Fatty tissue of breast  1-125.dcm
# 1  Breast_MRI_002         Fatty tissue of breast  1-030.dcm
# 2  Breast_MRI_002         Fatty tissue of breast  1-073.dcm
# 3  Breast_MRI_002  Mammary Fibroglandular Tissue  1-116.dcm
# 4  Breast_MRI_002  Mammary Fibroglandular Tissue  1-073.dcm
#
#                                Full Descriptive Path
# 0  Duke-Breast-Cancer-MRI/Breast_MRI_002/01-01-19...
# 1  Duke-Breast-Cancer-MRI/Breast_MRI_002/01-01-19...
# 2  Duke-Breast-Cancer-MRI/Breast_MRI_002/01-01-19...
# 3  Duke-Breast-Cancer-MRI/Breast_MRI_002/01-01-19...
# 4  Duke-Breast-Cancer-MRI/Breast_MRI_002/01-01-19...

# %% [markdown]
# ## Load Train_Ids CSV

# %%
bc_train_ids_df = pd.read_csv("/media/james/My Passport/Jetson_TX2_CMPE258/duke-breast-cancer-mri/train_ids.csv")
bc_train_ids_df.head()
# Out:
#                 0
# 0  Breast_MRI_002
# 1  Breast_MRI_008
# 2  Breast_MRI_018
# 3  Breast_MRI_020
# 4  Breast_MRI_047

# %% [markdown]
# ## Load Test_Ids CSV

# %%
bc_test_ids_df = pd.read_csv("/media/james/My Passport/Jetson_TX2_CMPE258/duke-breast-cancer-mri/test_ids.csv")
bc_test_ids_df.head()
# Out:
#                 0
# 0  Breast_MRI_014
# 1  Breast_MRI_026
# 2  Breast_MRI_187
# 3  Breast_MRI_197
# 4  Breast_MRI_231
